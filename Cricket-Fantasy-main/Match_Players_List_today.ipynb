# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
URL = 'https://www.cricbuzz.com/live-cricket-scorecard/46081/gt-vs-srh-40th-match-indian-premier-league-2022'

# %%
data = requests.get(URL).text
soup = BeautifulSoup(data, 'html.parser')

# %%
BASE_URL = 'https://www.cricbuzz.com'
players = {}
player_data = soup.find_all('a',class_='margin0 text-black text-hvr-underline')
for player in player_data:
    player_id = player['href'].split('/')[2]
    link = BASE_URL + player['href']
    name = player.get_text().split(' (')[0]
    players[player_id] = [name,link,'','']
players['1465']
# Out:
# ['Wriddhiman Saha',
#  'https://www.cricbuzz.com/profiles/1465/wriddhiman-saha',
#  '',
#  '']

# %%
# cb-col cb-col-20 cb-col-rt , cb-col cb-col-60 cb-lst-itm-sm
# updating image of player
for id in players.keys():
    URL = players[id][1]
    data = requests.get(URL).text
    soup = BeautifulSoup(data, 'html.parser')
    img = soup.find_all('div','cb-col cb-col-20 cb-col-rt')[0].find_all('img')[0]
    players[id][2] = (BASE_URL+img['src'])

    # updating player role
    roles = soup.find_all('div',class_='cb-col cb-col-60 cb-lst-itm-sm')[2]
    players[id][3] = roles.get_text().lstrip().rstrip()

# %%
players
# Out:
# {'1465': ['Wriddhiman Saha',
#   'https://www.cricbuzz.com/profiles/1465/wriddhiman-saha',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c171058/wriddhiman-saha.jpg',
#   'WK-Batsman'],
#  '9647': ['Hardik Pandya',
#   'https://www.cricbuzz.com/profiles/9647/hardik-pandya',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170666/hardik-pandya.jpg',
#   'Batting Allrounder'],
#  '11808': ['Shubman Gill',
#   'https://www.cricbuzz.com/profiles/11808/shubman-gill',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c171042/shubman-gill.jpg',
#   'Batsman'],
#  '10499': ['Abhinav Manohar',
#   'https://www.cricbuzz.com/profiles/10499/abhinav-manohar',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/abhinav-manohar.jpg',
#   'Batsman'],
#  '6349': ['David Miller',
#   'https://www.cricbuzz.com/profiles/6349/david-miller',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170687/david-miller.jpg',
#   'Batsman'],
#  '9693': ['Rahul Tewatia',
#   'https://www.cricbuzz.com/profiles/9693/rahul-tewatia',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c196288/rahul-tewatia.jpg',
#   'Batting Allrounder'],
#  '10738': ['Rashid Khan',
#   'https://www.cricbuzz.com/profiles/10738/rashid-khan',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170857/rashid-khan.jpg',
#   'Bowler'],
#  '11220': ['Alzarri Joseph',
#   'https://www.cricbuzz.com/profiles/11220/alzarri-joseph',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c152877/alzarri-joseph.jpg',
#   'Bowler'],
#  '10692': ['Lockie Ferguson',
#   'https://www.cricbuzz.com/profiles/10692/lockie-ferguson',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170749/lockie-ferguson.jpg',
#   'Bowler'],
#  '14172': ['Yash Dayal',
#   'https://www.cricbuzz.com/profiles/14172/yash-dayal',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/yash-dayal.jpg',
#   'Bowler'],
#  '7909': ['Mohammed Shami',
#   'https://www.cricbuzz.com/profiles/7909/mohammed-shami',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170684/mohammed-shami.jpg',
#   'Bowler'],
#  '1472': ['Pradeep Sangwan',
#   'https://www.cricbuzz.com/profiles/1472/pradeep-sangwan',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c153373/pradeep-sangwan.jpg',
#   'Bowler'],
#  '1649': ['Matthew Wade',
#   'https://www.cricbuzz.com/profiles/1649/matthew-wade',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c156205/matthew-wade.jpg',
#   'WK-Batsman'],
#  '6293': ['Varun Aaron',
#   'https://www.cricbuzz.com/profiles/6293/varun-aaron',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c171087/varun-aaron.jpg',
#   'Bowler'],
#  '8182': ['Jayant Yadav',
#   'https://www.cricbuzz.com/profiles/8182/jayant-yadav',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226388/jayant-yadav.jpg',
#   'Bowler'],
#  '8204': ['Vijay Shankar',
#   'https://www.cricbuzz.com/profiles/8204/vijay-shankar',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170664/vijay-shankar.jpg',
#   'Batting Allrounder'],
#  '8298': ['Gurkeerat Singh Mann',
#   'https://www.cricbuzz.com/profiles/8298/gurkeerat-singh-mann',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226548/gurkeerat-singh-mann.jpg',
#   'Batsman'],
#  '11595': ['Ravisrinivasan Sai Kishore',
#   'https://www.cricbuzz.com/profiles/11595/ravisrinivasan-sai-kishore',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226507/ravisrinivasan-sai-kishore.jpg',
#   'Bowler'],
#  '12779': ['Darshan Nalkande',
#   'https://www.cricbuzz.com/profiles/12779/darshan-nalkande',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/darshan-nalkande.jpg',
#   'Bowler'],
#  '13213': ['Rahmanullah Gurbaz',
#   'https://www.cricbuzz.com/profiles/13213/rahmanullah-gurbaz',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226320/rahmanullah-gurbaz.jpg',
#   'WK-Batsman'],
#  '13750': ['Dominic Drakes',
#   'https://www.cricbuzz.com/profiles/13750/dominic-drakes',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226329/dominic-drakes.jpg',
#   'Bowler'],
#  '13866': ['Sai Sudharsan',
#   'https://www.cricbuzz.com/profiles/13866/sai-sudharsan',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/sai-sudharsan.jpg',
#   'Batsman'],
#  '15452': ['Noor Ahmad',
#   'https://www.cricbuzz.com/profiles/15452/noor-ahmad',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226316/noor-ahmad.jpg',
#   'Bowler'],
#  '6326': ['Kane Williamson',
#   'https://www.cricbuzz.com/profiles/6326/kane-williamson',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170733/kane-williamson.jpg',
#   'Batsman'],
#  '9406': ['Nicholas Pooran',
#   'https://www.cricbuzz.com/profiles/9406/nicholas-pooran',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170810/nicholas-pooran.jpg',
#   'WK-Batsman'],
#  '12086': ['Abhishek Sharma',
#   'https://www.cricbuzz.com/profiles/12086/abhishek-sharma',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c153963/abhishek-sharma.jpg',
#   'Bowling Allrounder'],
#  '9012': ['Rahul Tripathi',
#   'https://www.cricbuzz.com/profiles/9012/rahul-tripathi',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226470/rahul-tripathi.jpg',
#   'Batsman'],
#  '9582': ['Aiden Markram',
#   'https://www.cricbuzz.com/profiles/9582/aiden-markram',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170645/aiden-markram.jpg',
#   'Batsman'],
#  '10919': ['Shashank Singh',
#   'https://www.cricbuzz.com/profiles/10919/shashank-singh',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/shashank-singh.jpg',
#   'Batsman'],
#  '10357': ['Jagadeesha Suchith',
#   'https://www.cricbuzz.com/profiles/10357/jagadeesha-suchith',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226508/jagadeesha-suchith.jpg',
#   'Bowler'],
#  '1726': ['Bhuvneshwar Kumar',
#   'https://www.cricbuzz.com/profiles/1726/bhuvneshwar-kumar',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c170689/bhuvneshwar-kumar.jpg',
#   'Bowler'],
#  '14565': ['Marco Jansen',
#   'https://www.cricbuzz.com/profiles/14565/marco-jansen',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226306/marco-jansen.jpg',
#   'Bowling Allrounder'],
#  '19027': ['Umran Malik',
#   'https://www.cricbuzz.com/profiles/19027/umran-malik',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226275/umran-malik.jpg',
#   'Bowler'],
#  '10225': ['T Natarajan',
#   'https://www.cricbuzz.com/profiles/10225/t-natarajan',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c198676/t-natarajan.jpg',
#   'Bowler'],
#  '8136': ['Sean Abbott',
#   'https://www.cricbuzz.com/profiles/8136/sean-abbott',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c191413/sean-abbott.jpg',
#   'Bowling Allrounder'],
#  '9688': ['Ravikumar Samarth',
#   'https://www.cricbuzz.com/profiles/9688/ravikumar-samarth',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/ravikumar-samarth.jpg',
#   'Batsman'],
#  '9746': ['Shreyas Gopal',
#   'https://www.cricbuzz.com/profiles/9746/shreyas-gopal',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226505/shreyas-gopal.jpg',
#   'Bowling Allrounder'],
#  '10693': ['Glenn Phillips',
#   'https://www.cricbuzz.com/profiles/10693/glenn-phillips',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226323/glenn-phillips.jpg',
#   'WK-Batsman'],
#  '10945': ['Washington Sundar',
#   'https://www.cricbuzz.com/profiles/10945/washington-sundar',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c171035/washington-sundar.jpg',
#   'Batting Allrounder'],
#  '11893': ['Vishnu Vinod',
#   'https://www.cricbuzz.com/profiles/11893/vishnu-vinod',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/vishnu-vinod.jpg',
#   'WK-Batsman'],
#  '12089': ['Priyam Garg',
#   'https://www.cricbuzz.com/profiles/12089/priyam-garg',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226310/priyam-garg.jpg',
#   'Batsman'],
#  '13136': ['Kartik Tyagi',
#   'https://www.cricbuzz.com/profiles/13136/kartik-tyagi',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226311/kartik-tyagi.jpg',
#   'Bowler'],
#  '13646': ['Romario Shepherd',
#   'https://www.cricbuzz.com/profiles/13646/romario-shepherd',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226370/romario-shepherd.jpg',
#   'Bowler'],
#  '14282': ['Fazalhaq Farooqi',
#   'https://www.cricbuzz.com/profiles/14282/fazalhaq-farooqi',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226317/fazalhaq-farooqi.jpg',
#   'Bowler'],
#  '14628': ['Abdul Samad',
#   'https://www.cricbuzz.com/profiles/14628/abdul-samad',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c226276/abdul-samad.jpg',
#   'Batsman'],
#  '15766': ['Saurabh Dubey',
#   'https://www.cricbuzz.com/profiles/15766/saurabh-dubey',
#   'https://www.cricbuzz.com/a/img/v1/152x152/i1/c182026/saurabh-dubey.jpg',
#   'Bowler']}
